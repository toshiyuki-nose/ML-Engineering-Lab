# %% [markdown]
# ## 1_9_Putting_it_All_Together.ipynb

# %% [markdown]
# In this recipe, we will repeat the same steps as before, but we will redo the configuration and data splitting, and try out a new algorithm called k-Nearest Neighbors.

# %%
## 1. First, import the model from the scikit-learn library, and then split the data in a balanced manner.


import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#load the classifying models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

iris = datasets.load_iris()
X = iris.data[:, :2]  #load the first two features of the iris data 
y = iris.target #load the target of the iris data

from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state = 0)

# %%
## 2. Construct two types of KNN models by specifying different values ​​for the `n_neighbors` parameter.
## Note that the number of folds is 10. 10-fold cross-validation is widely used in the machine learning community, including in data science competitions.

from sklearn.model_selection import cross_val_score
knn_3_clf = KNeighborsClassifier(n_neighbors = 3)
knn_5_clf = KNeighborsClassifier(n_neighbors = 5)

knn_3_scores = cross_val_score(knn_3_clf, X_train, y_train, cv=10)
knn_5_scores = cross_val_score(knn_5_clf, X_train, y_train, cv=10)

# %%
## 3. Calculate and output the accuracy to select a model.


print("knn_3 mean scores: ", knn_3_scores.mean(), "knn_3 std: ",knn_3_scores.std())
print("knn_5 mean scores: ", knn_5_scores.mean(), " knn_5 std: ",knn_5_scores.std())
# Out:
# knn_3 mean scores:  0.7674242424242425 knn_3 std:  0.06079987947646456
# knn_5 mean scores:  0.7946969696969697  knn_5 std:  0.06996407972517492

# %% [markdown]
# This is an example of hyperparameter optimization.

# %% [markdown]
# Stepping Up

# %%
## 4. You might be able to calculate the accuracy of the KNN model more quickly by running a simple loop.
## The output below shows that n_neighbors=4 is a good choice.

all_scores = []
for n_neighbors in range(3,9,1):
    knn_clf = KNeighborsClassifier(n_neighbors = n_neighbors)
    all_scores.append((n_neighbors, cross_val_score(knn_clf, X_train, y_train, cv=10).mean()))
sorted(all_scores, key = lambda x:x[1], reverse = True)
# Out:
# [(4, np.float64(0.8393939393939395)),
#  (7, np.float64(0.8227272727272726)),
#  (6, np.float64(0.8219696969696969)),
#  (8, np.float64(0.8045454545454545)),
#  (5, np.float64(0.7946969696969697)),
#  (3, np.float64(0.7674242424242425))]

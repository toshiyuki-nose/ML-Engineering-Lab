# %% [markdown]
# ## 2-8_Putting_it_all_together_with_Pipelines

# %%
## 1. Load the Iris dataset and randomly introduce missing values.

from sklearn.datasets import load_iris
from sklearn.datasets import load_iris
import numpy as np

iris = load_iris()
iris_data = iris.data

mask = np.random.binomial(
    1,
    .25,
    iris_data.shape
).astype(bool)

iris_data[mask] = np.nan

iris_data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, nan, 1.4, nan],
#        [4.7, 3.2, 1.3, 0.2],
#        [nan, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, nan]])

# %%
## 2. Build a pipeline that imputes missing values and applies PCA.

from sklearn import pipeline, preprocessing, decomposition
from sklearn.impute import SimpleImputer


pca = decomposition.PCA()
imputer = SimpleImputer()


pipe = pipeline.Pipeline([
    ('imputer', imputer),
    ('pca', pca)
])

iris_data_transformed = pipe.fit_transform(iris_data)

iris_data_transformed[:5]
# Out:
# array([[-2.62186641, -0.00682068, -0.1999654 ,  0.23534602],
#        [-2.32414475, -0.25591019,  0.80246459, -0.06989012],
#        [-2.80363086, -0.42130437, -0.10230964,  0.02173817],
#        [-2.27436836,  0.59342845, -0.30183296, -0.31152761],
#        [-2.33728595, -0.03032178,  0.75674144,  0.42935643]])

# %%
## 3. Create the same pipeline using make_pipeline and inspect its steps.

pipe2 = pipeline.make_pipeline(imputer, pca)

pipe2.steps
# Out:
# [('simpleimputer', SimpleImputer()), ('pca', PCA())]

# %%
## 4. Transform the Iris dataset using the pipeline created with make_pipeline.

iris_data_transformed2 = pipe2.fit_transform(iris_data)

iris_data_transformed2[:5]
# Out:
# array([[-2.62186641, -0.00682068, -0.1999654 ,  0.23534602],
#        [-2.32414475, -0.25591019,  0.80246459, -0.06989012],
#        [-2.80363086, -0.42130437, -0.10230964,  0.02173817],
#        [-2.27436836,  0.59342845, -0.30183296, -0.31152761],
#        [-2.33728595, -0.03032178,  0.75674144,  0.42935643]])

# %%
## 5. Set the number of PCA components to two through the pipeline.

pipe2.set_params(pca__n_components=2)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('pca', PCA(n_components=2))])

# %%
## 6. Transform the Iris dataset into two principal components.

iris_data_transformed3 = pipe2.fit_transform(iris_data)

iris_data_transformed3[:5]
# Out:
# array([[-2.62186641, -0.00682068],
#        [-2.32414475, -0.25591019],
#        [-2.80363086, -0.42130437],
#        [-2.27436836,  0.59342845],
#        [-2.33728595, -0.03032178]])

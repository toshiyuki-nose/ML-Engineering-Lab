# %% [markdown]
# ## 3-3_Using_factor_analysis_for_decomposition

# %%
## 1. Load the Iris dataset and reduce it to two dimensions using factor analysis.

from sklearn import datasets
iris = datasets.load_iris()
iris_X = iris.data

from sklearn.decomposition import FactorAnalysis



fa = FactorAnalysis(n_components=2)
iris_two_dim = fa.fit_transform(iris.data)
iris_two_dim[:5]
# Out:
# array([[-1.32761727, -0.56131076],
#        [-1.33763854, -0.00279765],
#        [-1.40281483,  0.30634949],
#        [-1.30104274,  0.71882683],
#        [-1.33342439, -0.36458899]])
